# %%
import numpy as np
import matplotlib.pyplot as plt
scores = np.load('training_size.npy')

# %%
scores
# Out:
# array([[0.89106145, 0.97487002, 0.89106145],
#        [0.90758621, 0.9788702 , 0.90758621],
#        [0.89606742, 0.96545693, 0.89606742],
#        [0.90659341, 0.98543273, 0.90659341],
#        [0.90659341, 0.98716852, 0.90659341],
#        [0.90659341, 0.98716852, 0.90659341]])

# %%
train_sizes = [50, 100, 250, 500, 1000, 1500]

# %%
plt.plot(train_sizes, scores[:, 0], label="In-Domain")
# plt.plot(train_sizes, scores[:, 1], label="Out-Domain (Claude)")
# plt.plot(train_sizes, scores[:, 2], label="Out-Domain (WP)")
# plt.plot(train_sizes, scores[:, 3], label="Out-Domain (Reuter)")
# plt.plot(train_sizes, scores[:, 4], label="Out-Domain (Essay)")

# %%
plt.plot(train_sizes, scores[:, 1], label="Out-Domain (Claude)")

# %%
plt.plot(train_sizes, scores[:, 2], label="Out-Domain (WP)")
